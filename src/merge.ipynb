# %%
import pandas as pd

df1 = pd.read_excel('J1-League.xlsx')
df2 = pd.read_excel('Albirex Niigata.xlsx')

# '선수이름'을 기준으로 병합 (inner join: 두 파일 모두에 있는 선수만 남김)
merged = pd.merge(df1, df2, on='player', how='outer')

# 만약 한쪽에만 있는 선수도 모두 포함하고 싶다면 how='outer' 사용
# merged = pd.merge(df1, df2, on='선수이름', how='outer')

# 결과 저장
merged.to_excel('merged.xlsx', index=False)
# Out:
# c:\BigData\.venv\Lib\site-packages\openpyxl\reader\workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df1 = pd.read_excel('J1-League.xlsx')
#       4 df2 = pd.read_excel('Albirex Niigata.xlsx')
#       6 # '선수이름'을 기준으로 병합 (inner join: 두 파일 모두에 있는 선수만 남김)
#
# File c:\BigData\.venv\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
# ...
